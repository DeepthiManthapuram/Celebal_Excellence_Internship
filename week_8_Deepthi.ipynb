# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepthiManthapuram/Celebal_Excellence_Internship/blob/main/week_8_Deepthi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧠 Single Agent Pipeline Project
#
# ## Problem Statement
# Build a **Single-Agent Smart Assistant** that:
# - Understands user queries
# - Routes tasks based on intent
# - Uses tools when required
# - Returns structured JSON output
#
# ### The agent should handle:
# - Math queries → Calculator Tool
# - Keyword extraction → Keyword Tool
# - General queries → Direct response
#
# ---
# ### 🛠️ What You Need to Implement
# - Agent logic
# - Conditional routing
# - Tool integration
# - Basic error handling
#
# ### 🚀 Bonus
# - Improve routing
# - Add logging
# - Add more tools

# %%
import json
import re

# %%
# 🛠️ TOOL 1: Calculator

def calculator(expression: str) -> str:
    """Evaluate a mathematical expression."""
    try:
        return str(eval(expression))
    except Exception:
        return "Error in calculation"

# %%
# 🛠️ TOOL 2: Keyword Extractor

def extract_keywords(text: str) -> list:
    """Extract keywords from text."""
    try:
        words = text.split()
        keywords = list(set([w.lower() for w in words if len(w) > 4]))
        return keywords[:5]
    except Exception:
        return []

# %% [markdown]
# ## 🤖 Implement Agent Logic Below
#
# 👉 Use conditional routing:
# - If query contains "calculate" → use calculator
# - If query contains "keywords" → use keyword extractor
# - Else → general response

# %%
# 🤖 AGENT FUNCTION (TO IMPLEMENT)

def agent(query: str):
    """
    Single-Agent Smart Assistant
    """

    print(f"[LOG] Received Query: {query}")

    query_lower = query.lower()

    try:

        # -------------------------------
        # Calculator Routing
        # -------------------------------
        if "calculate" in query_lower:

            print("[LOG] Routing → Calculator Tool")

            expression = query_lower.replace("calculate", "").strip()

            result = calculator(expression)

            return {
                "type": "calculation",
                "result": result
            }

        # -------------------------------
        # Keyword Routing
        # -------------------------------
        elif "keywords" in query_lower:

            print("[LOG] Routing → Keyword Extractor")

            text = re.sub(
                r"extract\s+keywords\s+from",
                "",
                query,
                flags=re.IGNORECASE
            ).strip()

            text = re.sub(
                r"keywords",
                "",
                text,
                flags=re.IGNORECASE
            ).strip()

            result = extract_keywords(text)

            return {
                "type": "keywords",
                "result": result
            }

        # -------------------------------
        # General Response
        # -------------------------------
        else:

            print("[LOG] Routing → General Response")

            return {
                "type": "general",
                "result": "Hello! I can perform calculations and extract keywords. Please include 'calculate' or 'keywords' in your query."
            }

    except Exception as e:

        print("[LOG] Error:", e)

        return {
            "type": "error",
            "result": str(e)
        }

# %% [markdown]
# ## 📦 Expected Output Format
#
# ```
# {
#   "type": "calculation / keywords / general / error",
#   "result": ...
# }
# ```

# %%
# 🧪 Test Cases

queries = [
    "Calculate 20 + 5",
    "Extract keywords from Artificial Intelligence is transforming industries",
    "What is machine learning?"
]

for q in queries:
    print("Query:", q)
    print("Response:", agent(q))
    print("-" * 50)
# Out:
# Query: Calculate 20 + 5
# [LOG] Received Query: Calculate 20 + 5
# [LOG] Routing → Calculator Tool
# Response: {'type': 'calculation', 'result': '25'}
# --------------------------------------------------
# Query: Extract keywords from Artificial Intelligence is transforming industries
# [LOG] Received Query: Extract keywords from Artificial Intelligence is transforming industries
# [LOG] Routing → Keyword Extractor
# Response: {'type': 'keywords', 'result': ['transforming', 'industries', 'intelligence', 'artificial']}
# --------------------------------------------------
# Query: What is machine learning?
# [LOG] Received Query: What is machine learning?
# [LOG] Routing → General Response
# Response: {'type': 'general', 'result': "Hello! I can perform calculations and extract keywords. Please include 'calculate' or 'keywords' in your query."}
# --------------------------------------------------

# %%
# 🎯 Interactive Mode

while True:
    user_input = input("Enter query (type 'exit' to stop): ")
    if user_input.lower() == "exit":
        break
    print("Response:", agent(user_input))
# Out:
# Enter query (type 'exit' to stop): calculate 25 + 15
# [LOG] Received Query: calculate 25 + 15
# [LOG] Routing → Calculator Tool
# Response: {'type': 'calculation', 'result': '40'}
# Enter query (type 'exit' to stop): Calculate (10 + 5) * 2
# [LOG] Received Query: Calculate (10 + 5) * 2
# [LOG] Routing → Calculator Tool
# Response: {'type': 'calculation', 'result': '30'}
# Enter query (type 'exit' to stop): keywords Machine Learning is transforming healthcare
# [LOG] Received Query: keywords Machine Learning is transforming healthcare
# [LOG] Routing → Keyword Extractor
# Response: {'type': 'keywords', 'result': ['healthcare', 'learning', 'transforming', 'machine']}
# Enter query (type 'exit' to stop): Hello
# [LOG] Received Query: Hello
# [LOG] Routing → General Response
# Response: {'type': 'general', 'result': "Hello! I can perform calculations and extract keywords. Please include 'calculate' or 'keywords' in your query."}
# Enter query (type 'exit' to stop): calculate 10//
# ...
